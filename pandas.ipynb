# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('MagicBricks.csv')

# %%
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft DataSource
# 0  Ready_to_move  New_Property  Builder_Floor       NaN   Original
# 1  Ready_to_move  New_Property      Apartment    6667.0   Original
# 2  Ready_to_move        Resale      Apartment    6667.0   Original
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(4) # head is bascially work how many data you seen
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
#
#                                  Locality  Parking     Price         Status  \
# 0                        Rohini Sector 25      1.0   6500000  Ready_to_move
# 1  J R Designers Floors, Rohini Sector 24      1.0   5000000  Ready_to_move
# 2     Citizen Apartment, Rohini Sector 13      1.0  15500000  Ready_to_move
# 3                        Rohini Sector 24      1.0   4200000  Ready_to_move
#
#     Transaction           Type  Per_Sqft DataSource
# 0  New_Property  Builder_Floor       NaN   Original
# 1  New_Property      Apartment    6667.0   Original
# 2        Resale      Apartment    6667.0   Original
# 3        Resale  Builder_Floor    6667.0   Original

# %%
df.tail(1) #Last rows print
# Out:
#         Area  BHK  Bathroom      Furnishing           Locality  Parking  \
# 1268  2000.0    3       3.0  Semi-Furnished  Chittaranjan Park      2.0
#
#          Price         Status Transaction           Type  Per_Sqft  \
# 1268  42000000  Ready_to_move      Resale  Builder_Floor   21000.0
#
#                DataSource
# 1268  Present (2024-2025)

# %%
df.shape
# Out:
# (1269, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1269 entries, 0 to 1268
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1269 non-null   float64
#  1   BHK          1269 non-null   int64
#  2   Bathroom     1267 non-null   float64
#  3   Furnishing   1264 non-null   object
#  4   Locality     1269 non-null   object
#  5   Parking      1236 non-null   float64
#  6   Price        1269 non-null   int64
#  7   Status       1269 non-null   object
#  8   Transaction  1269 non-null   object
#  9   Type         1264 non-null   object
#  10  Per_Sqft     1028 non-null   float64
#  11  DataSource   1269 non-null   object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 119.1+ KB

# %%
#Agr object dikha to mtlb String

# %%
df.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1269.000000  1269.000000  1267.000000  1236.000000  1.269000e+03
# mean    1465.889661     2.795902     2.557222     1.933657  2.134684e+07
# std     1562.610006     0.954046     1.041251     6.254039  2.556263e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.800000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.590000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1028.000000
# mean    15702.099222
# std     21042.155064
# min      1259.000000
# 25%      6444.250000
# 50%     11538.000000
# 75%     18055.000000
# max    183333.000000

# %%
df['Area']
# Out:
# 0        800.0
# 1        750.0
# 2        950.0
# 3        600.0
# 4        650.0
#          ...
# 1264    2500.0
# 1265    1100.0
# 1266    1350.0
# 1267     600.0
# 1268    2000.0
# Name: Area, Length: 1269, dtype: float64

# %%
df['Parking']
# Out:
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
#        ...
# 1264    3.0
# 1265    2.0
# 1266    1.0
# 1267    1.0
# 1268    2.0
# Name: Parking, Length: 1269, dtype: float64

# %%
df[['Area','Parking','Bathroom']]
# Out:
#         Area  Parking  Bathroom
# 0      800.0      1.0       2.0
# 1      750.0      1.0       2.0
# 2      950.0      1.0       2.0
# 3      600.0      1.0       2.0
# 4      650.0      1.0       2.0
# ...      ...      ...       ...
# 1264  2500.0      3.0       4.0
# 1265  1100.0      2.0       2.0
# 1266  1350.0      1.0       3.0
# 1267   600.0      1.0       1.0
# 1268  2000.0      2.0       3.0
#
# [1269 rows x 3 columns]

# %%
df.iloc[2:4]
# Out:
#     Area  BHK  Bathroom      Furnishing                             Locality  \
# 2  950.0    2       2.0       Furnished  Citizen Apartment, Rohini Sector 13
# 3  600.0    2       2.0  Semi-Furnished                     Rohini Sector 24
#
#    Parking     Price         Status Transaction           Type  Per_Sqft  \
# 2      1.0  15500000  Ready_to_move      Resale      Apartment    6667.0
# 3      1.0   4200000  Ready_to_move      Resale  Builder_Floor    6667.0
#
#   DataSource
# 2   Original
# 3   Original

# %%
df.iloc[:,[4,5,11]]
# Out:
#                                                Locality  Parking  \
# 0                                      Rohini Sector 25      1.0
# 1                J R Designers Floors, Rohini Sector 24      1.0
# 2                   Citizen Apartment, Rohini Sector 13      1.0
# 3                                      Rohini Sector 24      1.0
# 4     Rohini Sector 24 carpet area 650 sqft status R...      1.0
# ...                                                 ...      ...
# 1264                                  Greater Kailash I      3.0
# 1265                                        Vasant Kunj      2.0
# 1266                                          Janakpuri      1.0
# 1267                                        Uttam Nagar      1.0
# 1268                                  Chittaranjan Park      2.0
#
#                DataSource
# 0                Original
# 1                Original
# 2                Original
# 3                Original
# 4                Original
# ...

# %%
df.head() 
# Filtering dataframe based on a given condition
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft DataSource
# 0  Ready_to_move  New_Property  Builder_Floor       NaN   Original
# 1  Ready_to_move  New_Property      Apartment    6667.0   Original
# 2  Ready_to_move        Resale      Apartment    6667.0   Original
# ...

# %%
mask=df['Locality']=='Rohini Sector 25'
print(mask)
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1264    False
# 1265    False
# 1266    False
# 1267    False
# 1268    False
# Name: Locality, Length: 1269, dtype: bool

# %%
df[mask]
# Out:
#      Area  BHK  Bathroom      Furnishing          Locality  Parking    Price  \
# 0   800.0    3       2.0  Semi-Furnished  Rohini Sector 25      1.0  6500000
# 11  870.0    3       2.0  Semi-Furnished  Rohini Sector 25      1.0  7700000
# 26  800.0    3       2.0  Semi-Furnished  Rohini Sector 25      1.0  7000000
# 28   28.0    2       2.0       Furnished  Rohini Sector 25      1.0  5000000
#
#            Status   Transaction           Type  Per_Sqft DataSource
# 0   Ready_to_move  New_Property  Builder_Floor       NaN   Original
# 11  Ready_to_move  New_Property  Builder_Floor    6154.0   Original
# 26  Ready_to_move        Resale  Builder_Floor    8750.0   Original
# 28  Ready_to_move  New_Property      Apartment    8750.0   Original

# %%
def get_Locality(Locality):
    mask=df['Locality']==Locality
    return df[mask].shape[0]

# %%
get_Locality('Rohini Sector 24')
# Out:
# 11

# %%
mask1=df['Locality']=='Rohini Sector 25'
mask2=df['BHK']>2

df[mask1  & mask2].shape[0]
# Out:
# 3

# %%
df[mask1 | mask2].shape[1]
# Out:
# 12

# %%
#The value_count function use
df['Price'].value_counts()
# Out:
# Price
# 15000000    30
# 25000000    21
# 30000000    21
# 6000000     20
# 20000000    20
#             ..
# 10200000     1
# 21900000     1
# 5300000      1
# 3950000      1
# 42000000     1
# Name: count, Length: 285, dtype: int64

# %%
import matplotlib.pyplot as plt
df['BHK'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='BHK'>

# %%
df['BHK'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='BHK'>

# %%
df['Status'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['BHK'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
